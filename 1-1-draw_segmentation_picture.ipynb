# %%
import numpy as np
import matplotlib.pyplot as plt
import itertools

# %%
one_img = plt.imread(r"D:\OneDrive - tmu.edu.tw\AI_Competition\肺腺癌病理切片影像之腫瘤氣道擴散偵測競賽 II：運用影像分割作法於切割STAS輪廓\Train_images\00000000.jpg")
one_msk = plt.imread(r"D:\OneDrive - tmu.edu.tw\AI_Competition\肺腺癌病理切片影像之腫瘤氣道擴散偵測競賽 II：運用影像分割作法於切割STAS輪廓\Train_Mask\mask_00000000.jpg")

# %%
one_img.shape, one_msk.shape
# Out:
# ((942, 1716, 3), (942, 1716))

# %%
plt.figure(figsize = (20, 10))
plt.subplot(2, 1, 1)
plt.imshow(one_img)
plt.subplot(2, 1, 2)
plt.imshow(one_msk)
plt.show()

# %%
np.unique(one_msk)
# Out:
# array([  0,   1,   2,   3,   4,   5,   6,   7, 248, 249, 250, 251, 252,
#        253, 254, 255], dtype=uint8)

# %%
one_img_mask = one_img.copy()
for height, width in itertools.product(range(one_msk.shape[0]), range(one_msk.shape[1])):
    if one_msk[height, width] > 150:
        one_img_mask[height][width][0] = 255

# %%
plt.imshow(one_img_mask)
plt.show()

# %%
# Out:
# 229
